# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_x = pd.read_csv(r"data\train_dat_s2019.csv",header = None)
df_y = pd.read_csv(r"data\train_labels_s2019.csv", header = None)
test_x = pd.read_csv(r"data\test_dat_s2019.csv", header = None)

# %%
df_x
# Out:
#        0        1        2        3        4        5        6        7      \
# 0   -1.63583  0.06435  1.05320  1.60307 -0.04371 -0.39382 -1.88455  1.41656
# 1    1.30003  1.30126  0.47716  0.70103  1.27967  0.17905 -0.32945  0.05359
# 2   -0.73783 -0.25034  0.98175  0.38186 -0.25728  0.36855 -0.88419 -0.75638
# 3    0.86905 -1.40565  1.11303 -0.01740 -0.30502 -0.18245  1.46454 -2.36837
# 4   -0.64344 -0.68258  1.21138  0.73271 -0.38489  1.56170 -0.48992  0.02401
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 595  0.04706  0.32748 -0.11844  0.06316  0.99881 -0.14911 -0.41069 -0.80076
# 596 -0.24891 -1.00132  1.37253  0.61077 -1.00842 -1.36037  1.56966 -0.49202
# 597  0.24611 -0.62979 -1.19828  0.84294 -0.23009 -0.25326  1.17789 -0.62975
# 598  0.05470  0.68396  0.01891  1.06366  0.15074  0.37982  0.00445 -0.07579
# 599  1.12198  0.37804  1.26588 -0.27502 -0.76932  0.30638  0.78935 -0.61013
#
# ...

# %%
df_y
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# ..  ..
# 595  1
# 596  1
# 597  0
# 598  0
# 599  1
#
# [600 rows x 1 columns]

# %%
# Out:
#      0        1        2        3        4        5        6        7      \
# 0 -1.63583  0.06435  1.05320  1.60307 -0.04371 -0.39382 -1.88455  1.41656
# 2 -0.73783 -0.25034  0.98175  0.38186 -0.25728  0.36855 -0.88419 -0.75638
# 4 -0.64344 -0.68258  1.21138  0.73271 -0.38489  1.56170 -0.48992  0.02401
#
#      8        9      ...    39986    39987    39988    39989    39990  \
# 0  1.63031  0.28513  ... -0.07203 -1.66527  0.37898 -2.05577 -0.24134
# 2  1.05881 -0.45570  ... -0.19261 -0.07095 -0.59214  1.22232 -0.91384
# 4  1.22007  0.10662  ... -0.92540 -0.27032 -0.44844 -0.21069 -1.08481
#
#      39991    39992    39993    39994    39995
# 0  0.30498 -1.32387 -1.35241 -2.18302 -0.15691
# 2  0.22730 -1.02186 -1.26768  0.76001  1.16394
# 4  0.26295  0.30614  0.93400  0.95722 -0.77802
#
# [3 rows x 39996 columns]
